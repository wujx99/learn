# %% [markdown]
# # {{ title }}
#
# ## 学习目标
#
# -
#
# ## 前置知识
#
# -

# %% [markdown]
# ## 核心心智模型
#
# 先解释机制以及接下来要观察的现象。

# %%
import random

import torch

SEED = 42
random.seed(SEED)
torch.manual_seed(SEED)
print(f"PyTorch: {torch.__version__}")

# %% [markdown]
# ## 从最小实验开始
#
# 说明实验目标、张量形状和预期现象。

# %% [markdown]
# ## 常见误区与排查
#
# ## 自测与练习
#
# ## 相关知识与论文
#
# ## 下一步
